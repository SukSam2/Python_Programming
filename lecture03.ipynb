# %% [markdown]
# # 파이썬 프로그래밍 03
# ### Part 4

# %% [markdown]
# ### **목차**
# #### 10장. GUI Programming
# #### 11장. Web Programming
#
# --------
# -------
# <br>
# <br>
# <br>

# %% [markdown]
# ## Part 4 - 10장 | GUI Programming
# #### User Interfaces
#
# * 종류
#     * CLI(Command Line Interfaces)
#         * Click, Cement, Cliff
#     * GUI(Graphical User Interface)
#         * **Tkinter**, (PyQT, PySide and Qt for Python), WxPython, Python GTX+ 3, Kivy
#     * Web Interface
#         * **Flask**, Django, Pyramid
#
# <br>
#
# -----
#
# <br>
#
#
# ## TKinter
# ### Tkinter (the Python interface for Tk)
# * 개요
#     * TK 인터페이스, Tk를 위한 파이썬 인터페이스
#     * TCL 스크립트 언어를 위한 GUI 확장으로 개발되었음
#     * 핵심 = 윈도우 가젯 (라디오, 메세지, 메모 등 위젯)
#         * 위젯을 컴포넌트로 만든 것이 tk inter
#         * **위젯이 바로 오브젝트**
#         * **윈도우도 오브젝트**
#             * 오브젝트마다 서열(Hierarchy)이 존재
#             * 각각의 서열마다 init 시켜서 사용함
#
# <br>
#
# * Top-level-windows
#     * tk_chooseColor - 사용자가 색상을 선택할 수 있는 대화 상자가 나타난다.
#     * tk_chooseDirectory - 사용자가 디렉토리 선택할 수 있는 대화 상자가 나타난다.
#     * tk_dialog - 모달 대화 상자를 만들고 응답을 기다린다.
#     * tk_getOpenFile - 사용자가 열 파일을 선택할 수 있는 대화 상자가 나타난다.
#     * tk_getSaveFile - 사용자가 저장할 파일을 선택할 수 있는 대화 상자가 나타난다.
#     * tk_messageBox – 메시지 창을 열고 응답을 기다린다.
#     * tk_popup - 팝업 메뉴기 보인다.
#     * toplevel -최상위 위젯을 만들고 조작한다.
#
# <br>
#
# * Tk는 세 위치 관리자(geometry managers)를  제공한다.
#     * place - widget을 절대 위치에 배치한다.
#     * grid - widget을 그리드로 배치한다.
#     * pack - widget을 빈 부분에 배치한다
#
# <br>
#
# #### Hello Tkinter Label
#
# https://gitlab.com/skflyai-pyhton/part4/-/blob/main/Ch10/label_01.py
# 여기서 파일들 이용
#
# hello.py

# %%
import tkinter as tk

root = tk.Tk()

w = tk.Label(root, text="Hello Tkinter!")
w.pack()

root.mainloop()

# %% [markdown]
# 엄청 조그만 창이 뜬다.
#
# root는 윈도우 오브젝트이고 다음에 윈도우로 뭔가 하려면 꼭 파라미터로 들어가야겠다.
# Label이라는 오브젝트 하나 생성, text 옵션으로 "Hello TKinter!"인 것.
# 오브젝트를 pack, 윈도우에 적절히 배치해라.
# mainloop() 그려주세요.
#
# -> 터미널 윈도우 2개 나오도록 해보자.

# %%
import tkinter as tk

root = tk.Tk()

w1 = tk.Label(root, text="Hello Tkinter11!")
w1.pack()

w2 = tk.Label(root, text="Hello Tkinter22!")
w2.pack()

#root.mainloop()

# %% [markdown]
# <br>
#
# ##### Using the images in Labels

# %%
import tkinter as tk

root = tk.Tk()
logo = tk.PhotoImage(file="python_logo_small.png")

w1 = tk.Label(root, image=logo).pack(side="right")

explanation = """At present, only GIF and PPM/PGM
formats are supported, but an interface 
exists to allow additional image file
formats to be added easily."""

w2 = tk.Label(root, 
              justify=tk.LEFT,
              padx = 10, 
              text=explanation).pack(side="left")
root.mainloop()

# %% [markdown]
# <br>
# <br>
#
#
# ##### Message Widget
#
# master = tk.Tk() 마스터 생성
#
# * message 위젯과 label 위젯
#     * Message 위젯은 label 위젯과 기능이 유사하지만 텍스트를 표시할 때 더 유연하다.
#     예를 들어, label 위젯은 단일 글꼴로만 텍스트를 표시할 수 있는 반면 Message 위젯은 글꼴을 변경할 수 있다.
#
# <br>
#
# * message 위젯 옵션 아주 많다.

# %%
import tkinter as tk
master = tk.Tk()
whatever_you_do = """Whatever you do will be insignificant, \
but it is very important that you do it.\n(Mahatma Gandhi)"""
msg = tk.Message(master, text = whatever_you_do)
msg.config(bg='lightgreen', font=('times', 24, 'italic'))
msg.pack()
tk.mainloop()

# %% [markdown]
# <br>
# <br>
#
# ##### Buttons
# 클릭 이벤트를 generate 해서 클릭이 됐음을 알려준다.
# 텍스트와 이미지 포함 가능
#
# button1.py

# %%
import tkinter as tk


def write_slogan():
    print("Tkinter is easy to use!")

root = tk.Tk()
frame = tk.Frame(root)
frame.pack()

button = tk.Button(frame, 
                   text="QUIT", 
                   #fg= 'red',
                   command=quit)
button.config(fg='red')
button.pack(side=tk.LEFT)
slogan = tk.Button(frame,
                   text="Hello",
                   command=write_slogan)
slogan.pack(side=tk.LEFT)

root.mainloop()

# %% [markdown]
# 터미널에 나타난다. 원래 런칭한 프로그램 밑에 나타날 것이다.
# print() 명령은 std.out을 말한다.
# debugging 시 어디쯤에서 확인하는 용도로 사용 가능하다. 윈도우에 안나타나도 내가 보는 command 창에서 출력되기 때문에.
#
# <br>
# <br>
#
# #### Variable Classes
# 보통 radio 버튼은 다수 중 하나.
# 이와같이 variable들을 얻을 수 있다.
#
# * 제어 변수
#     x = StringVar() # Holds a string; default value ""
#     x = IntVar() # Holds an integer; default value 0
#     x = DoubleVar() # Holds a float; default value 0.0
#     x = BooleanVar() # Holds a boolean, returns 0 for False and 1 for True
#
# * 변수의 현재 값 얻으려면 get() 메서드 호출해야 한다.
# * 변수의 값은 set() 메서드로 변경할 수 있다.
#
# <br>
#
# ##### Radio buttons
#
# radio_01.py
# radio_02.py

# %%
import tkinter as tk

root = tk.Tk()

v = tk.IntVar()

tk.Label(root, 
        text="""Choose a 
programming language:""",
        justify = tk.LEFT,
        padx = 20).pack()

tk.Radiobutton(root, 
               text="Python",
               padx = 20, 
               variable=v, 
               value=1).pack(anchor=tk.W)

tk.Radiobutton(root, 
               text="Perl",
               padx = 20, 
               variable=v, 
               value=2).pack(anchor=tk.W)

root.mainloop()

# %%
import tkinter as tk

root = tk.Tk()

v = tk.IntVar()
v.set(1)  # initializing the choice, i.e. Python

languages = [("Python", 101),
   	     ("Perl", 102),
    	     ("Java", 103),
             ("C++", 104),
             ("C", 105)]

def ShowChoice():
    print(v.get())   # 클릭하면 가져온다.

tk.Label(root, 
         text="""Choose your favourite 
programming language:""",
         justify = tk.LEFT,
         padx = 20).pack()

for language, val in languages:
    tk.Radiobutton(root, 
                   text=language,
                   padx = 20, 
                   variable=v, 
                   command=ShowChoice,
                   value=val).pack(anchor=tk.W)

root.mainloop()

# %% [markdown]
# <br>
#
# ##### indicator
#
# radio_03.py

# %%
import tkinter as tk

root = tk.Tk()

v = tk.IntVar()
v.set(1)  # initializing the choice, i.e. Python

languages = [("Python", 101),
   	     ("Perl", 102),
    	     ("Java", 103),
             ("C++", 104),
             ("C", 105)]

def ShowChoice():
    print(v.get())

tk.Label(root, 
         text="""Choose your favourite 
programming language:""",
         justify = tk.LEFT,
         padx = 20).pack()

for language, val in languages:
    tk.Radiobutton(root, 
                   text=language,
                   indicatoron=0,
                   width = 20,
                   padx = 20, 
                   variable=v, 
                   command=ShowChoice,
                   value=val).pack(anchor=tk.W)

root.mainloop()

# %% [markdown]
# ##### Chekboxes
# On/Off 두 가지 상태만 선택 가능
#
# checkbox_01.py
# checkbox_02.py
# checkbox_03.py

# %%
from tkinter import *

master = Tk()
var1 = IntVar()
Checkbutton(master, text="male", variable=var1).grid(row=0, sticky=W)
var2 = IntVar()
Checkbutton(master, text="female", variable=var2).grid(row=1, sticky=W)
mainloop()
print(var1.get())
print(var2.get())

# %%
from tkinter import *

master = Tk()

def var_states():
   print("male: %d,\nfemale: %d" % (var1.get(), var2.get()))

Label(master, text="Your sex:").grid(row=0, sticky=W)
var1 = IntVar()
Checkbutton(master, text="male", variable=var1).grid(row=1, sticky=W)
var2 = IntVar()
Checkbutton(master, text="female", variable=var2).grid(row=2, sticky=W)
Button(master, text='Quit', command=master.quit).grid(row=3, sticky=W, pady=4)
Button(master, text='Show', command=var_states).grid(row=4, sticky=W, pady=4)
mainloop()

# %%
#!/usr/bin/python3

from tkinter import *

class Checkbar(Frame):
   def __init__(self, parent=None, picks=[], side=LEFT, anchor=W):
      Frame.__init__(self, parent)
      self.vars = []
      for pick in picks:
         var = IntVar()
         chk = Checkbutton(self, text=pick, variable=var)
         chk.pack(side=side, anchor=anchor, expand=YES)
         self.vars.append(var)
   def state(self):
      return map((lambda var: var.get()), self.vars)

      
if __name__ == '__main__':
   root = Tk()
   lng = Checkbar(root, ['Python', 'Ruby', 'Perl', 'C++'])
   tgl = Checkbar(root, ['English','German'])
   lng.pack(side=TOP,  fill=X)
   tgl.pack(side=LEFT)
   lng.config(relief=GROOVE, bd=2)

   def allstates(): 
      print(list(lng.state()), list(tgl.state()))
   Button(root, text='Quit', command=root.quit).pack(side=RIGHT)
   Button(root, text='Peek', command=allstates).pack(side=RIGHT)
   root.mainloop()

# %% [markdown]
# <br>
# <br>
#
# --------
#
# <br>
# <br>
#
#
# ##### Entry Widgets
#
# entry_01.py
# entry_02.py
# entry_03.py
#
#
# ##### Canvas Widgets
#
# canvas_01 ~ canvas_11.py
#
#
# ##### Sliders Widget
#
# sliders_01 ~ sliders_04.py
#
# ##### Text Widget
#
# text_01.py ~ text_04.py
#
# ##### Dialogs Widget
#
# dialogs_01.py ~ dialogs_03.py
#
# ##### Menu
#
# ##### Events

# %%
# events_01.py

from tkinter import *
def hello(event):
    print("Single Click, Button-1")
def quit(event):
    print("Double Click, so let's stop")
    import sys
    sys.exit()

widget = Button(None, text = "Mouse Clicks")
widget.pack()
widget.bind('<Button-1>', hello)
widget.bind('<Double-1>', quit)
widget.mainloop()
# Out:
# Single Click, Button-1
# Single Click, Button-1
# Single Click, Button-1

# %%
# events_02.py
from tkinter import *

def motion(event):
    # print("Mouse position: (%s %s)" %(event.x, event.y))
    print(f"Mouse position: {event.x}, {event.y}")
    return

master = Tk()
whatever_you_do = "Whatever you do will be insignificant, but it is very important that you do it.\n(Mahatma Gandhi)"

msg = Message(master, text = whatever_you_do)
msg.config(bg = 'lightgreen', font=('times', 24, 'italic'))
msg.bind('<Motion>', motion)
msg.pack()
mainloop()
# Out:
# Mouse position: 123, 191
# Mouse position: 113, 190
# Mouse position: 104, 188
# Mouse position: 93, 185
# Mouse position: 82, 183
# Mouse position: 71, 181
# Mouse position: 62, 179
# Mouse position: 48, 175
# Mouse position: 36, 172
# Mouse position: 25, 169
# Mouse position: 15, 166
# Mouse position: 7, 163
# Mouse position: 4, 73
# Mouse position: 8, 71
# Mouse position: 11, 70
# Mouse position: 14, 68
# Mouse position: 17, 66
# Mouse position: 21, 66
# Mouse position: 25, 65
# Mouse position: 28, 64
# Mouse position: 32, 63
# Mouse position: 35, 62
# Mouse position: 40, 61
# Mouse position: 43, 61
# Mouse position: 47, 60
# Mouse position: 52, 59
# Mouse position: 55, 58
# Mouse position: 59, 57
# Mouse position: 62, 56
# Mouse position: 65, 56
# Mouse position: 68, 56
# Mouse position: 71, 56
# Mouse position: 74, 56
# Mouse position: 76, 56
# Mouse position: 78, 56
# Mouse position: 80, 56
# Mouse position: 81, 56
# Mouse position: 82, 56
# Mouse position: 83, 56
# ...
